# %%
import pandas as pd

# %%
data = pd.Series(['January','Febrary','March','April','May'],
                  index =['First','Second','Third','Fourth','Fifyh'])
display(data)
# Out:
# First     January
# Second    Febrary
# Third       March
# Fourth      April
# Fifyh         May
# dtype: object

# %%
data.loc['First']
# Out:
# 'January'

# %%
data.loc[['First','Second']]
# Out:
# First     January
# Second    Febrary
# dtype: object

# %%
data.iloc[0]
# Out:
# 'January'

# %%
data.iloc[[0,2]]
# Out:
# First    January
# Third      March
# dtype: object

# %%
data = pd.Series(list(range(10, 1001)))

# %%
print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# -70

# %%
data = pd.Series(list(range(10, 1001)))

# %%
data.iloc[990]
# Out:
# 1000

# %%
df = pd.DataFrame({'col1':[1,2],'col2':[3,4]})
display(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df = pd.DataFrame([ [1,2,3], [2,3,4] ],
                  columns = ['Foo', 'bar', 'Baz'],
                  index = ['Foorbaz', 'Foorbar'])
display(df)
# Out:
#          Foo  bar  Baz
# Foorbaz    1    2    3
# Foorbar    2    3    4

# %%
pd.DataFrame({'Тестовая колонка':[1,5]})
# Out:
#    Тестовая колонка
# 0                 1
# 1                 5

# %%
pd.read_csv('data_sf.csv')
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
football = pd.read_csv('data_sf.csv')
football.head()
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
football.tail()
# Out:
#        Unnamed: 0                Name  Age Nationality              Club  \
# 12892       13121        J. Lundstram   19     England   Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden    Trelleborgs FF
# 12894       13123           B. Worman   16     England  Cambridge United
# 12895       13124      D. Walker-Rice   17     England   Tranmere Rovers
# 12896       13125           G. Nugent   16     England   Tranmere Rovers
#
#          Value  Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 12892  1100000  1000       CM        34         38  ...         43         45
# 12893    60000  1000       ST        23         52  ...         43         42
# 12894    60000  1000       ST        25         40  ...         55         41
# 12895    60000  1000       RW        44         50  ...         50         46
# 12896    60000  1000       CM        41         34  ...         33         43
#
# ...

# %%
football.head(2)
# Out:
#    Unnamed: 0               Name  Age Nationality          Club      Value  \
# 0           0           L. Messi   31   Argentina  FC Barcelona  110500000
# 1           1  Cristiano Ronaldo   33    Portugal      Juventus   77000000
#
#      Wage Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0  565000       RF        84         95  ...         75         96       33
# 1  405000       ST        84         94  ...         85         95       28
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
# 1              31             23         7          11         15
#
#    GKPositioning  GKReflexes
# 0             14           8
# 1             14          11
#
# [2 rows x 42 columns]

# %%
football.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
football.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
football.describe(include=['object'])
# Out:
#                 Name Nationality             Club Position
# count          12897       12897            12897    12897
# unique         12326         156              650       27
# top     J. Rodríguez     England  Shonan Bellmare       GK
# freq               9        1368               30     1641

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
football.sum()
# Out:
# Unnamed: 0                                                  85185212
# Name               L. MessiCristiano RonaldoNeymar JrDe GeaK. De ...
# Age                                                           319786
# Nationality        ArgentinaPortugalBrazilSpainBelgiumBelgiumCroa...
# Club               FC BarcelonaJuventusParis Saint-GermainManches...
# Value                                                    27244260000
# Wage                                                        96954000
# Position           RFSTLWGKRCMLFRCMRSRCBGKSTLCMCBLCMLDMLFSTCAMGKG...
# Crossing                                                      607144
# Finishing                                                     552976
# HeadingAccuracy                                               647462
# ShortPassing                                                  722580
# Volleys                                                       519685
# Dribbling                                                     676599
# ...

# %%
football.Age.mean()
# Out:
# 24.795378770256647

# %%
football.Composure.count()
# Out:
# 12897

# %%
football.ShortPassing.std()
# Out:
# 14.740435689517149

# %%
football.Wage.sum()
# Out:
# 96954000

# %%
football.Value.min()
# Out:
# 0

# %%
football[football.Age>football.Age.mean()]
# Out:
#        Unnamed: 0               Name  Age   Nationality  \
# 0               0           L. Messi   31     Argentina
# 1               1  Cristiano Ronaldo   33      Portugal
# 2               2          Neymar Jr   26        Brazil
# 3               3             De Gea   27         Spain
# 4               4       K. De Bruyne   27       Belgium
# ...           ...                ...  ...           ...
# 12746       12975      Teng Shangkun   27      China PR
# 12749       12978         M. Mansour   26  Saudi Arabia
# 12767       12996          Sun Qibin   26      China PR
# 12861       13090        Y. Uchimura   33         Japan
# 12873       13102      K. Pilkington   44       England
#
#                              Club      Value    Wage Position  Crossing  \
# 0                    FC Barcelona  110500000  565000       RF        84
# 1                        Juventus   77000000  405000       ST        84
# 2             Paris Saint-Germain  118500000  290000       LW        79
# ...

# %%
football[(football.Age < football.Age.mean())|
        (football.Club == 'FC Barcelona')]
# Out:
#        Unnamed: 0                Name  Age Nationality               Club  \
# 0               0            L. Messi   31   Argentina       FC Barcelona
# 7               7           L. Suárez   31     Uruguay       FC Barcelona
# 15             15           P. Dybala   24   Argentina           Juventus
# 16             16             H. Kane   24     England  Tottenham Hotspur
# 18             18       M. ter Stegen   26     Germany       FC Barcelona
# ...           ...                 ...  ...         ...                ...
# 12892       13121        J. Lundstram   19     England    Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden     Trelleborgs FF
# 12894       13123           B. Worman   16     England   Cambridge United
# 12895       13124      D. Walker-Rice   17     England    Tranmere Rovers
# 12896       13125           G. Nugent   16     England    Tranmere Rovers
#
#            Value    Wage Position  Crossing  Finishing  ...  Penalties  \
# ...

# %%
football[(football.Age < football.Age.mean())&
        (football.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
football[(football.Wage > football.Wage.mean())].SprintSpeed.mean()
# Out:
# 67.56638061585058

# %%
football[(football.Wage < football.Wage.mean())].SprintSpeed.mean()
# Out:
# 62.41425430560645

# %%
football[['Position','Wage']]
# Out:
#       Position    Wage
# 0           RF  565000
# 1           ST  405000
# 2           LW  290000
# 3           GK  260000
# 4          RCM  355000
# ...        ...     ...
# 12892       CM    1000
# 12893       ST    1000
# 12894       ST    1000
# 12895       RW    1000
# 12896       CM    1000
#
# [12897 rows x 2 columns]

# %%
football[football['Nationality'] == 'Brazil'].sum()
# Out:
# Unnamed: 0                                                   1433045
# Name               Neymar JrCasemiroCoutinhoMarceloThiago SilvaEd...
# Age                                                            11801
# Nationality        BrazilBrazilBrazilBrazilBrazilBrazilBrazilBraz...
# Club               Paris Saint-GermainReal MadridFC BarcelonaReal...
# Value                                                     2190865000
# Wage                                                         7348000
# Position           LWCDMLWLBRCBGKCAMLBLMCDMGKLDMCBCBLBLBCDMLDMSTR...
# Crossing                                                       21580
# Finishing                                                      20356
# HeadingAccuracy                                                23634
# ShortPassing                                                   25613
# Volleys                                                        20179
# Dribbling                                                      24199
# ...

# %%
football[(football.HeadingAccuracy > 50)].Age.mean()
# Out:
# 25.58771113179944

# %%
football[football['Reactions'] == 86]
# Out:
#      Unnamed: 0             Name  Age Nationality                     Club  \
# 9             9         J. Oblak   25    Slovenia          Atlético Madrid
# 15           15        P. Dybala   24   Argentina                 Juventus
# 38           38       G. Higuaín   30   Argentina                    Milan
# 47           47        R. Lukaku   25     Belgium        Manchester United
# 57           57          Ederson   24      Brazil          Manchester City
# 58           58          S. Mané   26     Senegal                Liverpool
# 61           61  Roberto Firmino   26      Brazil                Liverpool
# 71           71  T. Alderweireld   29     Belgium        Tottenham Hotspur
# 75           75      Fernandinho   33      Brazil          Manchester City
# 76           76          Iniesta   34       Spain              Vissel Kobe
# 131         131     M. Mandžukić   32     Croatia                 Juventus
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football[football['Reactions'] == 96])
# Out:
#    Unnamed: 0               Name  Age Nationality      Club     Value    Wage  \
# 1           1  Cristiano Ronaldo   33    Portugal  Juventus  77000000  405000
#
#   Position  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 1       ST        84         94               89            81       87
#
#    Dribbling  Curve  FKAccuracy  LongPassing  BallControl  Acceleration  \
# 1         88     81          76           77           94            89
#
#    SprintSpeed  Agility  Reactions  Balance  ShotPower  Jumping  Stamina  \
# 1           91       87         96       70         95       95       88
#
#    Strength  LongShots  Aggression  Interceptions  Positioning  Vision  \
# 1        79         93          63             29           95      82
#
#    Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 1         85         95       28              31             23         7
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes
# ...

# %%
football[(football.Composure>0.9*football.Composure.max())&
         (football.Reactions>0.9*football.Reactions.max())].Age.min()
# Out:
# 24

# %%
football[(football.Age == football.Age.max())].Reactions.mean() - football[(football.Age == football.Age.min())].Reactions.mean()
# Out:
# 22.642857142857146

# %%
football['Nationality'].value_counts()
# Out:
# England      1368
# Germany       919
# Spain         671
# France        614
# Argentina     574
#              ...
# Rwanda          1
# Palestine       1
# Nicaragua       1
# Bermuda         1
# Grenada         1
# Name: Nationality, Length: 156, dtype: int64

# %%
football[(football.Value >= football.Value.mean())].Nationality.value_counts()
# Out:
# Spain         211
# Brazil        130
# France        123
# Argentina     122
# England       113
#              ...
# Tanzania        1
# Bulgaria        1
# Georgia         1
# Mauritania      1
# Cyprus          1
# Name: Nationality, Length: 98, dtype: int64

# %%
football[(football.GKReflexes == football.GKReflexes.max())& (football.Position == 'GK')].Wage.mean() / football[(football.GKHandling == football.GKHandling.max())& (football.Position == 'GK')].Wage.mean()
# Out:
# 2.765957446808511

# %%
football[(football.Aggression == football.Aggression.max())].ShotPower.mean() / football[(football.Aggression == football.Aggression.min())].ShotPower.mean()
# Out:
# 2.076923076923077

# %%
football['Club'].value_counts()
# Out:
# V-Varen Nagasaki     30
# Shonan Bellmare      30
# Vissel Kobe          29
# FC Emmen             29
# De Graafschap        29
#                      ..
# Dijon FCO             8
# GD Chaves             7
# Dinamo Zagreb         7
# Vitória Guimarães     7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
football['Position'].value_counts(normalize=True)*100
# Out:
# GK     12.723889
# ST     11.723657
# CB     10.878499
# CM      8.273242
# LB      7.769249
# RB      7.350547
# RM      5.939366
# LM      5.644724
# CDM     5.357835
# CAM     4.908118
# RCB     3.241064
# LCB     3.171280
# LW      1.876405
# RCM     1.860898
# RW      1.837637
# LCM     1.806622
# LDM     1.147554
# RDM     1.070016
# LS      0.938203
# RS      0.883926
# RWB     0.542762
# LWB     0.465224
# CF      0.395441
# LF      0.062030
# RF      0.046522
# LAM     0.046522
# RAM     0.038769
# Name: Position, dtype: float64

# %%
small_football = football[football.columns[0:7]].head(25)
s = small_football['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
s.index
# Out:
# IntervalIndex([(211750.0, 329500.0], (93528.999, 211750.0], (329500.0, 447250.0], (447250.0, 565000.0]],
#               closed='right',
#               dtype='interval[float64]')

# %%
s.index[3]
# Out:
# Interval(447250.0, 565000.0, closed='right')

# %%
s.index[3].left
# Out:
# 447250.0

# %%
s.index[3].right
# Out:
# 565000.0

# %%
small_football['Wage'] > s.index[3].left
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: Wage, dtype: bool

# %%
football['FKAccuracy'].value_counts(bins=5)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
football['Position'].nunique()
# Out:
# 27

# %%
len(football['Position'].unique())
# Out:
# 27

# %%
len(football['Position'].value_counts())
# Out:
# 27

# %%
football[football.Nationality == 'Spain'].Wage.value_counts(bins=4)/ football[(football.Nationality == 'Spain')].Name.value_counts().sum()* 100
# Out:
# (620.999, 95750.0]      97.019374
# (95750.0, 190500.0]      1.639344
# (190500.0, 285250.0]     0.894188
# (285250.0, 380000.0]     0.447094
# Name: Wage, dtype: float64

# %%
football[(football.Club == 'Manchester United')].Nationality.nunique()
# Out:
# 13

# %%
football[(football.Nationality == 'Brazil')& (football.Club == 'Juventus')].Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
football[football['Age'] >= 35].Club.value_counts()
# Out:
# Júbilo Iwata                           4
# Club Atlético Huracán                  4
# Chongqing Dangdai Lifan FC SWM Team    4
# San Martín de San Juan                 4
# Hokkaido Consadole Sapporo             4
#                                       ..
# Cádiz CF                               1
# Scunthorpe United                      1
# Club Necaxa                            1
# Al Nassr                               1
# Frosinone                              1
# Name: Club, Length: 296, dtype: int64

# %%
football[football['Nationality'] == 'Argentina'].Age.value_counts(bins=4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
football[(football.Nationality == 'Spain')& (football.Age == 21)].Age.value_counts() *100 / football[(football.Nationality == 'Spain')].Age.value_counts().sum()
# Out:
# 21    11.773472
# Name: Age, dtype: float64

# %%
football.groupby(['Position']).groups
# Out:
# {'CAM': Int64Index([   17,    31,    61,    66,    74,    80,    96,   101,   148,
#                177,
#              ...
#              12648, 12701, 12774, 12795, 12804, 12814, 12831, 12835, 12860,
#              12861],
#             dtype='int64', length=633),
#  'CB': Int64Index([   12,    42,    73,    89,   102,   104,   107,   115,   161,
#                167,
#              ...
#              12788, 12803, 12807, 12818, 12819, 12824, 12826, 12855, 12858,
#              12869],
#             dtype='int64', length=1403),
#  'CDM': Int64Index([   20,    27,    72,    75,   118,   127,   133,   165,   174,
#                180,
#              ...
#              12640, 12669, 12727, 12764, 12780, 12784, 12832, 12863, 12872,
#              12882],
#             dtype='int64', length=691),
#  'CF': Int64Index([  216,   265,   283,   733,   735,  1329,  2186,  2766,  3144,
#               3360,  3813,  4237,  4455,  4592,  4664,  5956,  6038,  6209,
# ...

# %%
grouped_football = football.groupby(['Position']).sum()
display(grouped_football)
# Out:
#           Unnamed: 0    Age       Value      Wage  Crossing  Finishing  \
# Position
# CAM          4047426  15216  1875705000   5500000     36066      36014
# CB           9871798  34407  1853715000   7476000     53059      40278
# CDM          4362394  17271  1146300000   4921000     34679      29548
# CF            389107   1170    94280000    248000      2627       3148
# CM           8666017  24655  1725835000   6194000     55663      50909
# GK          12004641  42188  2465605000   8784000     23233      19304
# LAM            12686    168    79475000    366000       426        400
# LB           6533552  24958  1431890000   6096000     61171      38486
# LCB          1837760  11049  1078335000   3989000     17525      12731
# LCM          1107908   6102  1006115000   3145000     13495      12480
# LDM           672621   3983   498680000   1516000      8225       7219
# LF             21760    223   218900000    601000       546        570
# ...

# %%
grouped_football = football.groupby(['Position'])['Wage'].sum()
display(grouped_football)
# Out:
# Position
# CAM     5500000
# CB      7476000
# CDM     4921000
# CF       248000
# CM      6194000
# GK      8784000
# LAM      366000
# LB      6096000
# LCB     3989000
# LCM     3145000
# LDM     1516000
# LF       601000
# LM      5440000
# LS      1866000
# LW      2945000
# LWB      347000
# RAM       59000
# RB      5034000
# RCB     4711000
# RCM     3241000
# RDM     1557000
# RF       714000
# RM      5098000
# RS      1537000
# RW      3276000
# RWB      420000
# ST     11873000
# Name: Wage, dtype: int64

# %%
grouped_football = football.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
print(grouped_football.head(8))
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# Name: Wage, dtype: int64

# %%
football.groupby(['Position'])[['Wage','Value']].mean()
# Out:
#                    Wage         Value
# Position
# CAM         8688.783570  2.963199e+06
# CB          5328.581611  1.321251e+06
# CDM         7121.562952  1.658900e+06
# CF          4862.745098  1.848627e+06
# CM          5805.060918  1.617465e+06
# GK          5352.833638  1.502502e+06
# LAM        61000.000000  1.324583e+07
# LB          6083.832335  1.429032e+06
# LCB         9753.056235  2.636516e+06
# LCM        13497.854077  4.318090e+06
# LDM        10243.243243  3.369459e+06
# LF         75125.000000  2.736250e+07
# LM          7472.527473  2.466174e+06
# LS         15421.487603  5.848430e+06
# LW         12169.421488  3.603099e+06
# LWB         5783.333333  1.931333e+06
# RAM        11800.000000  8.345000e+06
# RB          5310.126582  1.248940e+06
# RCB        11270.334928  3.009055e+06
# RCM        13504.166667  4.217604e+06
# RDM        11282.608696  2.692717e+06
# RF        119000.000000  2.636583e+07
# RM          6655.352480  2.138734e+06
# ...

# %%
football.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False).head(10)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06

# %%
football.groupby(['Club'])[['Wage','Value']].nunique()
# Out:
#                        Wage  Value
# Club
#  SSV Jahn Regensburg      7     17
# 1. FC Heidenheim 1846     8     18
# 1. FC Kaiserslautern      3     16
# 1. FC Köln                8     10
# 1. FC Magdeburg           8     18
# ...                     ...    ...
# Zagłębie Sosnowiec        2     18
# Çaykur Rizespor          11     21
# Örebro SK                 2     22
# Östersunds FK             5     17
# Śląsk Wrocław             4     21
#
# [650 rows x 2 columns]

# %%
football.groupby(['Club'])['Name'].count()
# Out:
# Club
#  SSV Jahn Regensburg     24
# 1. FC Heidenheim 1846    20
# 1. FC Kaiserslautern     23
# 1. FC Köln               10
# 1. FC Magdeburg          21
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          22
# Örebro SK                26
# Östersunds FK            20
# Śląsk Wrocław            24
# Name: Name, Length: 650, dtype: int64

# %%
football.groupby(['Club'])['Wage'].agg(['mean','median'])
# Out:
#                               mean  median
# Club
#  SSV Jahn Regensburg   3750.000000    3500
# 1. FC Heidenheim 1846  3800.000000    3000
# 1. FC Kaiserslautern   1434.782609    1000
# 1. FC Köln             9200.000000    4000
# 1. FC Magdeburg        4000.000000    4000
# ...                            ...     ...
# Zagłębie Sosnowiec     1080.000000    1000
# Çaykur Rizespor        5363.636364    4500
# Örebro SK              1384.615385    1000
# Östersunds FK          1950.000000    1000
# Śląsk Wrocław          2083.333333    2000
#
# [650 rows x 2 columns]

# %%
group=football.groupby(['Club'])['Wage'].agg(['mean','median'])
s=len(group[group['mean']==group['median']])
print(s)
# Out:
# 52

# %%
group=football.groupby(['Club'])['Wage'].agg(['mean','median'])
s=group[group['mean']==group['median']].max()
print(s)
# Out:
# mean      13000.0
# median    13000.0
# dtype: float64

# %%
group=football.groupby(['Club'])['Wage'].agg(['mean','median'])
s=group[group['mean']==group['median']].idxmax()
print(s)
# Out:
# mean      Cruzeiro
# median    Cruzeiro
# dtype: object

# %%
football.groupby(['Club'])['Wage'].max()
# Out:
# Club
#  SSV Jahn Regensburg      8000
# 1. FC Heidenheim 1846    14000
# 1. FC Kaiserslautern      3000
# 1. FC Köln               26000
# 1. FC Magdeburg           8000
#                          ...
# Zagłębie Sosnowiec        2000
# Çaykur Rizespor          13000
# Örebro SK                 2000
# Östersunds FK             8000
# Śląsk Wrocław             4000
# Name: Wage, Length: 650, dtype: int64

# %%
ch=football.groupby(['Club'])['Wage'].sum()
hc=ch['Chelsea']
print(hc)
# Out:
# 2035000

# %%
ar=football.groupby(['Nationality','Age'])['Wage'].max()
gen=ar['Argentina',20]
print(gen)
# Out:
# 54000

# %%
ar=football.groupby(['Nationality','Age'])['Wage'].max()
gen=ar['Argentina',30]
print(gen)
# Out:
# 300000

# %%
ar=football.groupby(['Nationality','Age'])['Wage'].min()
gen=ar['Argentina',30]
print(gen)
# Out:
# 1000

# %%
#1й способ 
#football.groupby([(football.Nationality == 'Argentina') & (football.Club == 'FC Barcelona')])[['Balance','Strength']].max()

#2й способ
#football[(football.Nationality == 'Argentina') & (football.Club == 'FC Barcelona')][['Balance','Strength']].max()


#3й способ
st=football.groupby(['Nationality','Club'])['Strength','Balance'].max()
mt=st.loc[('Argentina','FC Barcelona'),:]
print(mt)
# Out:
# Strength    59
# Balance     95
# Name: (Argentina, FC Barcelona), dtype: int64
# <ipython-input-16-4e3cc70db992>:19: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   st=football.groupby(['Nationality','Club'])['Strength','Balance'].max()

# %%
df2 = football.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
#print(df2)
display(df2)
# Out:
# Position                   CAM       CB      CDM      CF      CM       GK  \
# Club
#  SSV Jahn Regensburg       NaN   5000.0   5000.0     NaN  4000.0   5000.0
# 1. FC Heidenheim 1846   5000.0   7000.0      NaN     NaN  1000.0   4000.0
# 1. FC Kaiserslautern       NaN   1000.0   1000.0     NaN     NaN   1000.0
# 1. FC Köln                 NaN   1000.0  10000.0     NaN  3000.0  25000.0
# 1. FC Magdeburg            NaN   7000.0      NaN  4000.0     NaN   6000.0
# ...                        ...      ...      ...     ...     ...      ...
# Zagłębie Sosnowiec      2000.0   1000.0   1000.0     NaN     NaN   1000.0
# Çaykur Rizespor        11000.0  11000.0  13000.0     NaN     NaN   3000.0
# Örebro SK                  NaN   2000.0      NaN     NaN  1000.0   2000.0
# Östersunds FK           1000.0   1000.0      NaN  3000.0  8000.0   1000.0
# Śląsk Wrocław              NaN   1000.0   3000.0     NaN  1000.0   2000.0
#
# ...

# %%
df2.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
pivot = football.loc[football['Position'].isin(['GK'])].pivot_table(values=['Name'],
index=['Club'],
columns=['Position'],
aggfunc='count',
margins=True,
fill_value=0)
display(pivot)


pivot = football.pivot_table(index=['Position'],
                             columns=['Club'],
                             aggfunc='count',
                             fill_value=0)
round(pivot.loc['GK'].mean(),3)
# Out:
#                        Name
# Position                 GK   All
# Club
#  SSV Jahn Regensburg      3     3
# 1. FC Heidenheim 1846     2     2
# 1. FC Kaiserslautern      3     3
# 1. FC Köln                3     3
# 1. FC Magdeburg           3     3
# ...                     ...   ...
# Çaykur Rizespor           3     3
# Örebro SK                 3     3
# Östersunds FK             3     3
# Śląsk Wrocław             3     3
# All                    1641  1641
#
# [646 rows x 2 columns]
# 2.525

# %%
pivot = football.pivot_table(index=['Position'],
                             columns=['Club'],
                             aggfunc='count',
                             fill_value=0)
round(pivot.loc['GK'].mean(),3)
# Out:
# 2.525

# %%
pivot = football.pivot_table(values=['Name'], index=['Position'], columns=['Club'], aggfunc='count', fill_value=0)
display(pivot.loc['CM'].value_counts())
# Out:
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %%
df2 = football.pivot_table(columns = 'Nationality', index = 'Club', values = 'Wage', aggfunc = 'max', fill_value=0)
df2.loc['AS Monaco']['Russia']
# Out:
# 61000

# %%
df2 = football.pivot_table(columns = 'Position', index = 'Club', values = 'SprintSpeed', aggfunc = 'mean', fill_value=0)
display(df2.max().sort_values(ascending=False).head(3))
# Out:
# Position
# RS    94.0
# RM    94.0
# LM    94.0
# dtype: float64

# %%
df2 = football.pivot_table(columns = 'Club', index = 'Position', values = 'SprintSpeed', aggfunc = 'mean', fill_value=0)
display(df2.loc['ST'].sort_values(ascending=False).head(3))
# Out:
# Club
# Vitória      91.0
# Sydney FC    88.0
# CD Lugo      87.0
# Name: ST, dtype: float64
