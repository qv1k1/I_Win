# %% [markdown]
# # Строки в Python

# %% [markdown]
# Строка – это последовательность символов, заключенных в одинарные или двойные кавычки. При этом строка, как и список, – это упорядоченная последовательность элементов. Следовательно, из нее можно извлекать отдельные символы и срезы.

# %% [markdown]
# ### Как создать строку
#
# Строки всегда создаются одним из трех способов. Вы можете использовать одинарные, двойные и тройные кавычки. Давайте посмотрим

# %%
my_string = 'Hello World!'
my_string_2 = "Hello World"
type(my_string_2)
# Out:
# str

# %% [markdown]
# Однако если вы попытаетесь многострочный текст, то так не получится

# %%
my_string = 'Hello 
World!'
# Out:
#   File "<ipython-input-3-892285d9f4d7>", line 1
#     my_string = 'Hello
#                        ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# Можем использовать [экранированные последовательности](https://pythonworld.ru/tipy-dannyx-v-python/stroki-literaly-strok.html)

# %%
my_string = 'Hello \nWorld!'
print(my_string)
# Out:
# Hello
# World!

# %% [markdown]
# Можно использовать многострочные строки при помощи тройных кавычек. Кроме того, они позволяю внутри себя без проблем использовать кавычки обоих типов

# %%
multiline_string = """В такой "строке" мы можем
'использовать' все."""
print(multiline_string)
# Out:
# В такой "строке" мы можем
# 'использовать' все.

# %% [markdown]
# ### Функции и методы строк

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(...)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __sizeof__(self, /)
#  |      Return the size of the string in memory, in bytes.
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  capitalize(self, /)
#  |      Return a capitalized version of the string.
#  |
#  |      More specifically, make the first character have upper case and the rest lower
#  |      case.
#  |
#  |  casefold(self, /)
#  |      Return a version of the string suitable for caseless comparisons.
#  |
#  |  center(self, width, fillchar=' ', /)
#  |      Return a centered string of length width.
#  |
#  |      Padding is done using the specified fill character (default is a space).
#  |
#  |  count(...)
#  |      S.count(sub[, start[, end]]) -> int
#  |
#  |      Return the number of non-overlapping occurrences of substring sub in
#  |      string S[start:end].  Optional arguments start and end are
#  |      interpreted as in slice notation.
#  |
#  |  encode(self, /, encoding='utf-8', errors='strict')
#  |      Encode the string using the codec registered for encoding.
#  |
#  |      encoding
#  |        The encoding in which to encode the string.
#  |      errors
#  |        The error handling scheme to use for encoding errors.
#  |        The default is 'strict' meaning that encoding errors raise a
#  |        UnicodeEncodeError.  Other possible values are 'ignore', 'replace' and
#  |        'xmlcharrefreplace' as well as any other name registered with
#  |        codecs.register_error that can handle UnicodeEncodeErrors.
#  |
#  |  endswith(...)
#  |      S.endswith(suffix[, start[, end]]) -> bool
#  |
#  |      Return True if S ends with the specified suffix, False otherwise.
#  |      With optional start, test S beginning at that position.
#  |      With optional end, stop comparing S at that position.
#  |      suffix can also be a tuple of strings to try.
#  |
#  |  expandtabs(self, /, tabsize=8)
#  |      Return a copy where all tab characters are expanded using spaces.
#  |
#  |      If tabsize is not given, a tab size of 8 characters is assumed.
#  |
#  |  find(...)
#  |      S.find(sub[, start[, end]]) -> int
#  |
#  |      Return the lowest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Return -1 on failure.
#  |
#  |  format(...)
#  |      S.format(*args, **kwargs) -> str
#  |
#  |      Return a formatted version of S, using substitutions from args and kwargs.
#  |      The substitutions are identified by braces ('{' and '}').
#  |
#  |  format_map(...)
#  |      S.format_map(mapping) -> str
#  |
#  |      Return a formatted version of S, using substitutions from mapping.
#  |      The substitutions are identified by braces ('{' and '}').
#  |
#  |  index(...)
#  |      S.index(sub[, start[, end]]) -> int
#  |
#  |      Return the lowest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Raises ValueError when the substring is not found.
#  |
#  |  isalnum(self, /)
#  |      Return True if the string is an alpha-numeric string, False otherwise.
#  |
#  |      A string is alpha-numeric if all characters in the string are alpha-numeric and
#  |      there is at least one character in the string.
#  |
#  |  isalpha(self, /)
#  |      Return True if the string is an alphabetic string, False otherwise.
#  |
#  |      A string is alphabetic if all characters in the string are alphabetic and there
#  |      is at least one character in the string.
#  |
#  |  isascii(self, /)
#  |      Return True if all characters in the string are ASCII, False otherwise.
#  |
#  |      ASCII characters have code points in the range U+0000-U+007F.
#  |      Empty string is ASCII too.
#  |
#  |  isdecimal(self, /)
#  |      Return True if the string is a decimal string, False otherwise.
#  |
#  |      A string is a decimal string if all characters in the string are decimal and
#  |      there is at least one character in the string.
#  |
#  |  isdigit(self, /)
#  |      Return True if the string is a digit string, False otherwise.
#  |
#  |      A string is a digit string if all characters in the string are digits and there
#  |      is at least one character in the string.
#  |
#  |  isidentifier(self, /)
#  |      Return True if the string is a valid Python identifier, False otherwise.
#  |
#  |      Call keyword.iskeyword(s) to test whether string s is a reserved identifier,
#  |      such as "def" or "class".
#  |
#  |  islower(self, /)
#  |      Return True if the string is a lowercase string, False otherwise.
#  |
#  |      A string is lowercase if all cased characters in the string are lowercase and
#  |      there is at least one cased character in the string.
#  |
#  |  isnumeric(self, /)
#  |      Return True if the string is a numeric string, False otherwise.
#  |
#  |      A string is numeric if all characters in the string are numeric and there is at
#  |      least one character in the string.
#  |
#  |  isprintable(self, /)
#  |      Return True if the string is printable, False otherwise.
#  |
#  |      A string is printable if all of its characters are considered printable in
#  |      repr() or if it is empty.
#  |
#  |  isspace(self, /)
#  |      Return True if the string is a whitespace string, False otherwise.
#  |
#  |      A string is whitespace if all characters in the string are whitespace and there
#  |      is at least one character in the string.
#  |
#  |  istitle(self, /)
#  |      Return True if the string is a title-cased string, False otherwise.
#  |
#  |      In a title-cased string, upper- and title-case characters may only
#  |      follow uncased characters and lowercase characters only cased ones.
#  |
#  |  isupper(self, /)
#  |      Return True if the string is an uppercase string, False otherwise.
#  |
#  |      A string is uppercase if all cased characters in the string are uppercase and
#  |      there is at least one cased character in the string.
#  |
#  |  join(self, iterable, /)
#  |      Concatenate any number of strings.
#  |
#  |      The string whose method is called is inserted in between each given string.
#  |      The result is returned as a new string.
#  |
#  |      Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'
#  |
#  |  ljust(self, width, fillchar=' ', /)
#  |      Return a left-justified string of length width.
#  |
#  |      Padding is done using the specified fill character (default is a space).
#  |
#  |  lower(self, /)
#  |      Return a copy of the string converted to lowercase.
#  |
#  |  lstrip(self, chars=None, /)
#  |      Return a copy of the string with leading whitespace removed.
#  |
#  |      If chars is given and not None, remove characters in chars instead.
#  |
#  |  partition(self, sep, /)
#  |      Partition the string into three parts using the given separator.
#  |
#  |      This will search for the separator in the string.  If the separator is found,
#  |      returns a 3-tuple containing the part before the separator, the separator
#  |      itself, and the part after it.
#  |
#  |      If the separator is not found, returns a 3-tuple containing the original string
#  |      and two empty strings.
#  |
#  |  replace(self, old, new, count=-1, /)
#  |      Return a copy with all occurrences of substring old replaced by new.
#  |
#  |        count
#  |          Maximum number of occurrences to replace.
#  |          -1 (the default value) means replace all occurrences.
#  |
#  |      If the optional argument count is given, only the first count occurrences are
#  |      replaced.
#  |
#  |  rfind(...)
#  |      S.rfind(sub[, start[, end]]) -> int
#  |
#  |      Return the highest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Return -1 on failure.
#  |
#  |  rindex(...)
#  |      S.rindex(sub[, start[, end]]) -> int
#  |
#  |      Return the highest index in S where substring sub is found,
#  |      such that sub is contained within S[start:end].  Optional
#  |      arguments start and end are interpreted as in slice notation.
#  |
#  |      Raises ValueError when the substring is not found.
#  |
#  |  rjust(self, width, fillchar=' ', /)
#  |      Return a right-justified string of length width.
#  |
#  |      Padding is done using the specified fill character (default is a space).
#  |
#  |  rpartition(self, sep, /)
#  |      Partition the string into three parts using the given separator.
#  |
#  |      This will search for the separator in the string, starting at the end. If
#  |      the separator is found, returns a 3-tuple containing the part before the
#  |      separator, the separator itself, and the part after it.
#  |
#  |      If the separator is not found, returns a 3-tuple containing two empty strings
#  |      and the original string.
#  |
#  |  rsplit(self, /, sep=None, maxsplit=-1)
#  |      Return a list of the words in the string, using sep as the delimiter string.
#  |
#  |        sep
#  |          The delimiter according which to split the string.
#  |          None (the default value) means split according to any whitespace,
#  |          and discard empty strings from the result.
#  |        maxsplit
#  |          Maximum number of splits to do.
#  |          -1 (the default value) means no limit.
#  |
#  |      Splits are done starting at the end of the string and working to the front.
#  |
#  |  rstrip(self, chars=None, /)
#  |      Return a copy of the string with trailing whitespace removed.
#  |
#  |      If chars is given and not None, remove characters in chars instead.
#  |
#  |  split(self, /, sep=None, maxsplit=-1)
#  |      Return a list of the words in the string, using sep as the delimiter string.
#  |
#  |      sep
#  |        The delimiter according which to split the string.
#  |        None (the default value) means split according to any whitespace,
#  |        and discard empty strings from the result.
#  |      maxsplit
#  |        Maximum number of splits to do.
#  |        -1 (the default value) means no limit.
#  |
#  |  splitlines(self, /, keepends=False)
#  |      Return a list of the lines in the string, breaking at line boundaries.
#  |
#  |      Line breaks are not included in the resulting list unless keepends is given and
#  |      true.
#  |
#  |  startswith(...)
#  |      S.startswith(prefix[, start[, end]]) -> bool
#  |
#  |      Return True if S starts with the specified prefix, False otherwise.
#  |      With optional start, test S beginning at that position.
#  |      With optional end, stop comparing S at that position.
#  |      prefix can also be a tuple of strings to try.
#  |
#  |  strip(self, chars=None, /)
#  |      Return a copy of the string with leading and trailing whitespace removed.
#  |
#  |      If chars is given and not None, remove characters in chars instead.
#  |
#  |  swapcase(self, /)
#  |      Convert uppercase characters to lowercase and lowercase characters to uppercase.
#  |
#  |  title(self, /)
#  |      Return a version of the string where each word is titlecased.
#  |
#  |      More specifically, words start with uppercased characters and all remaining
#  |      cased characters have lower case.
#  |
#  |  translate(self, table, /)
#  |      Replace each character in the string using the given translation table.
#  |
#  |        table
#  |          Translation table, which must be a mapping of Unicode ordinals to
#  |          Unicode ordinals, strings, or None.
#  |
#  |      The table must implement lookup/indexing via __getitem__, for instance a
#  |      dictionary or list.  If this operation raises LookupError, the character is
#  |      left untouched.  Characters mapped to None are deleted.
#  |
#  |  upper(self, /)
#  |      Return a copy of the string converted to uppercase.
#  |
#  |  zfill(self, width, /)
#  |      Pad a numeric string with zeros on the left, to fill a field of the given width.
#  |
#  |      The string is never truncated.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  maketrans(...)
#  |      Return a translation table usable for str.translate().
#  |
#  |      If there is only one argument, it must be a dictionary mapping Unicode
#  |      ordinals (integers) or characters to Unicode ordinals, strings or None.
#  |      Character keys will be then converted to ordinals.
#  |      If there are two arguments, they must be strings of equal length, and
#  |      in the resulting dictionary, each character in x will be mapped to the
#  |      character at the same position in y. If there is a third argument, it
#  |      must be a string, whose characters will be mapped to None in the result.

# %%
# конкатенация (сложение строк)
s1 = 'spam '
s2 = 'eggs'
print(s1 + s2)
# Out:
# spam eggs

# %%
# умножение строки на число
'**' * 5
# Out:
# '**********'

# %%
# print('a' > 'c')
# print('a' > 'A')
# print('aba' > 'abc')
# print('Ё' > 'К')
# Out:
# False
# True
# False
# False

# %% [markdown]
# Строки в Python неизменяемым типом данных, поэтому все методы строк всегда будут возвращать новую строку, а не менять исходную.

# %%
my_string = 'Hello World!'

# %%
# приведение к верхнему регистру
print(my_string.upper())
print(my_string)
# Out:
# HELLO WORLD!
# Hello World!

# %%
# приведение к нижнему регистру
my_string.lower()
# Out:
# 'hello world!'

# %%
# первая буква строки в верхнем регистре
my_string.capitalize()
# Out:
# 'Hello world!'

# %%
# первая буква каждого слова в верхнем регистре
'my_string'.title()
# Out:
# 'My_String'

# %%
# заменяем подстроку в строке
my_string.replace('Hello', 'Goodbye')
# Out:
# 'Goodbye World!'

# %%
# метод find() ищет подстроку в строке и возвращает индекс первого элемента найденной подстроки. 
# если подстрока не найдена, то возвращает -1.
s = 'red blue orange white blue'
print(s.find('b'))
print(s.find('blue'))
# Out:
# 4
# 4

# %%
# определяем длину строки
len(my_string)
# Out:
# 12

# %%
# проверка вхождение подстроки в строку
my_string = 'Hello World'
target_string = 'World'
if target_string in my_string:
    print('found!')
else:
    print('not found')
# Out:
# found!

# %% [markdown]
# ### Списки и строки

# %%
queries_string = "смотреть сериалы онлайн,новости спорта,афиша кино,курс доллара,сериалы этим летом,курс по питону,сериалы про спорт"

# %%
# преобразование строки в список (например, из CSV-файла)
queries_string.split(',')
# Out:
# ['смотреть сериалы онлайн',
#  'новости спорта',
#  'афиша кино',
#  'курс доллара',
#  'сериалы этим летом',
#  'курс по питону',
#  'сериалы про спорт']

# %%
# преобразование списка в строку

','.join(['Столбец 1', 'Столбец 2', 'Столбец 3'])
# Out:
# 'Столбец 1,Столбец 2,Столбец 3'

# %% [markdown]
# ### [f-строки](https://python-scripts.com/f-strings)
#
# Добавляя префикс f к строке можно встраивать в нее произвольные выражения при помощи фигурных скобок – { }.

# %%
name = 'oleg'
lang = 'python'
my_str = f'Hello, my name is {name.capitalize()}, i know {lang} a bit'
print(my_str)
print(type(my_str))
# Out:
# Hello, my name is Oleg, i know python a bit
# <class 'str'>

# %% [markdown]
# Можно формировать многострочные f-строки

# %%
name = 'oleg'
lang = 'python'
my_str = (f'Hello, my name is '
          f'{name.capitalize()}, i know {lang} a bit')
print(my_str)
# Out:
# Hello, my name is Oleg, i know python a bit

# %%
phr = f'{10+30.555555 :.2%} is a number'
phr
# Out:
# '55.5555% is a number'

# %% [markdown]
# Индексация и срезы строк

# %%
my_string = 'Hello World'

# %%
my_string[0]
# Out:
# 'H'

# %%
my_string[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-bfdf6761080a> in <module>
# ----> 1 my_string[100]
#
# IndexError: string index out of range

# %%
my_string[-5]
# Out:
# 'W'

# %%
my_string[3:8]
# Out:
# 'lo Wo'

# %% [markdown]
# Важным отличием от списков является неизменяемость строк в Python. Нельзя перезаписать какой-то отдельный символ или срез в строке.

# %%
my_string[-1] = '!'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7470e2dc20b8> in <module>
# ----> 1 my_string[-1] = '!'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# **Практика**.
# Дана переменная, в которой хранится слово из латинских букв. Напишите код, который выводит на экран:
#
# среднюю букву, если число букв в слове нечетное;
# две средних буквы, если число букв четное.
#
# Примеры работы программы:
#
# word = 'test'
# Результат:
# es
#
# word = 'testing'
# Результат:
# t

# %%
word = 'test'

# %%
a = len(word)
if a % 2 == 0:
    print(word[int(a / 2 - 1)], word[int(a / 2)], sep='')
else:
    print(word[a // 2])
# Out:
# es

# %% [markdown]
# Напоминаем, что строки являются **итерируемыми объектами**.
#
# Следовательно, по ним можно проходиться циклами:

# %%
iter_string = 'Проитерируй меня!'

for symbol in iter_string:
    print(symbol, end = ' ')
# Out:
# П р о и т е р и р у й   м е н я !

# %% [markdown]
# **Практика**. Получим список, сло словами длиннее n букв

# %%
text = 'Python — высокоуровневый язык программирования, ориентированный на повышение производительности разработчика и читаемости кода.'
n = 4

# %%
words = []
for w in text.replace(',', '').replace('.', '').split():
    if len(w) > 4:
        words.append(w)
words
# Out:
# ['Python',
#  'высокоуровневый',
#  'программирования',
#  'ориентированный',
#  'повышение',
#  'производительности',
#  'разработчика',
#  'читаемости']

# %% [markdown]
# # Регулярные выражения
# Регулярные выражения (Regular Expressions, regex) – это строки, содержащие совокупность обычных символов и специальных метасимволов, которые описывают определенный шаблон.
#
# Эти шаблоны, к примеру, можно использовать для того, чтобы:
# - находить и заменять что-то в текстовых данных;
# - валидировать строковые поля.
#
# Шаблоны могут быть настолько сложными, что другими способами определить их будет крайне трудно.
#
# Одна из особенностей регулярных выражений в их универсальности, стоит вам выучить синтаксис, и вы сможете применять их в любом (почти) языке программирования (JavaScript, Java, VB, C #, C / C++, Python, Perl, Ruby, Delphi, R, Tcl, и многих других). Небольшие отличия касаются только наиболее продвинутых функций и версий синтаксиса, поддерживаемых движком.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# >Если у вас есть проблема, и вы собираетесь ее решать с помощью регулярных выражений, тогда у вас будет уже две проблемы.
#
# <cite>Шутка из интернетов (не шутка)</cite>. [Вот так](https://www.ex-parrot.com/~pdw/Mail-RFC822-Address.html) может выглядеть страшная регулярка.

# %% [markdown]
# ### Основы синтаксиса регулярных выражений

# %% [markdown]
# <table>
# <tbody>
# <tr>
# <td width="20%"><b>Последовательность</b></td>
# <td width="60%"><b>Описание</b></td>
# <td width="20%"><b>Аналог с []</b></td>
# </tr>
# <tr>
# <td>\d</td>
# <td>Любая цифра</td>
# <td>[0-9]</td>
# </tr>
# <tr>
# <td>\D</td>
# <td>Всё что угодно, кроме цифры</td>
# <td>[^0-9]</td>
# </tr>
# <tr>
# <td>\s</td>
# <td>Любой пробельный символ</td>
# <td>[ \t\n\r\f\v]</td>
# </tr>
# <tr>
# <td>\S</td>
# <td>Любой непробельный символ</td>
# <td>[^ \t\n\r\f\v]</td>
# </tr>
# <tr>
# <td>\w</td>
# <td>Любая буква, цифра, знак подчёркивания</td>
# <td>[a-zA-Z0-9_]</td>
# </tr>
# <tr>
# <td>\W</td>
# <td>Всё что угодно, кроме букв, цифр и знака подчёркивания</td>
# <td>[^a-zA-Z0-9_]</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# <table>
# <tbody>
# <tr>
# <td width="10%"><b>Символ</b></td>
# <td width="50%"><b>Пояснение</b></td>
# <td width="20%"><b>Пример выражения</b></td>
# <td width="20%"><b>Пример строки</b></td>
# </tr>
# <tr>
# <td>.</td>
# <td>Любой символ</td>
# <td>...</td>
# <td>A!#</td>
# </tr>
# <tr>
# <td>*</td>
# <td>Ноль и более&nbsp;совпадений с выражением, заданным в качестве образца&nbsp;</td>
# <td>123*</td>
# <td>123123123</td>
# </tr>
# <tr>
# <td>+</td>
# <td>Одно и более&nbsp;совпадений с выражением, заданным в качестве образца&nbsp;</td>
# <td>Ура!+</td>
# <td>Ура!Ура!</td>
# </tr>
# <tr>
# <td>?</td>
# <td>Ноль или одно&nbsp;совпадение с выражением, заданным в качестве образца&nbsp;</td>
# <td>один?</td>
# <td>один</td>
# </tr>
# <tr>
# <td>[ ]</td>
# <td>Совпадение с любым из символов, заключённым в скобки</td>
# <td>[a-z]</td>
# <td>b</td>
# </tr>
# <tr>
# <td>[^ ]</td>
# <td>Совпадение с любым из символов, отсутствующим в скобках</td>
# <td>[^a-z]</td>
# <td>5</td>
# </tr>
# <tr>
# <td>\</td>
# <td>Экранирует специальные символы (т.е. позволяет использовать символы типа '.', '*', '?' в роли обычных элементов строки)</td>
# <td>\*</td>
# <td>*</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### Квантификаторы
#     Квантификатор после символа или группы определяет, сколько раз предшествующее выражение может встречаться.
#
#     {n,m}        общее выражение, повторений может быть от n до m включительно.
#     {n,}        общее выражение, n и более повторений.
#     {,m}        общее выражение, не более m повторений.
#     {n}        общее выражение, ровно n повторений

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **raw string** – подавляет значение escape-последовательностей, обозначается префиксом r перед обычной строкой.
# Настоятельно рекомендуется использовать всегда при работе с регулярными выражениями для избежания проблем.

# %%
import re

# %%
# найдем идентификаторы пользователей в тексте
msg = 'В розыгрыше победили: id1234563, id4653, id461'

# %%
re.findall(r'id\d+', msg)
# Out:
# ['id1234563', 'id4653', 'id461']

# %% [markdown]
# **Практика**. Найдем хэштеги в твите

# %%
tweet = 'когда #эпидемия, то обязательно #оставайсядома'

# %%
re.findall(r'#\w{1,50}', tweet)
# Out:
# ['#эпидемия', '#оставайсядома']

# %%
# вытащим номера телефонов и текста
phone_numbers = 'Мария: 8-943-342-23-32 Александр: 8-323-432-23-67'

phone_pattern = r'\d-\d{3}-\d{3}-\d{2}-\d{2}'
re.findall(phone_pattern, phone_numbers)
# Out:
# ['8-943-342-23-32', '8-323-432-23-67']

# %%
text = """Что такое регулярные выражения и как их использовать? 
Говоря простым языком, регулярное выражение — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,
их поддерживает множество языков общего назначения: Python, Perl, R.
Так что изучение регулярных выражений рано или поздно пригодится."""
pattern = 'регулярн[а-я]+ выражен[а-я]+'
re.findall(pattern, text)
# Out:
# ['регулярные выражения', 'регулярное выражение', 'регулярных выражений']

# %% [markdown]
# **Практика**. Произведем замену "Регулярные выражения" во всех формах на "regex"

# %%
text = """Что такое регулярные выражения и как их использовать? 
Говоря простым языком, регулярное выражение — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,
их поддерживает множество языков общего назначения: Python, Perl, R.
Так что изучение регулярных выражений рано или поздно пригодится."""

# %%
re.sub(r'регулярн[а-я]+ выражен[а-я]+', 'regex', text)
# Out:
# 'Что такое regex и как их использовать? \nГоворя простым языком, regex — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,\nих поддерживает множество языков общего назначения: Python, Perl, R.\nТак что изучение regex рано или поздно пригодится.'

# %% [markdown]
# Простой способ удалить все знаки препинания

# %%
text = """Что такое регулярные выражения и как их использовать? 
Говоря простым языком, регулярное выражение — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,
их поддерживает множество языков общего назначения: Python, Perl, R.
Так что изучение регулярных выражений рано или поздно пригодится."""

re.sub(r'[^\w\s]', '', text)
# Out:
# 'Что такое регулярные выражения и как их использовать \nГоворя простым языком регулярное выражение  это последовательность символов используемая для поиска и замены текста в строке или файле Как уже было упомянуто\nих поддерживает множество языков общего назначения Python Perl R\nТак что изучение регулярных выражений рано или поздно пригодится'

# %% [markdown]
# Часть шаблона можно заключить в скобки (...). Это называется «скобочная группа».
# Это позволяет:
# - поместить часть шаблона в отдельную структуру (группу);
# - если установить квантификатор после скобок, то он будет применяться ко всему содержимому скобки, а не к одному символу.
#
# При наличии подгрупп в шаблоне можно ссылаться на них через их порядковый номер при помощи \1, \2, \3, …
#
# Группам можно давать собственные имена при помощи (?P<имя>...)

# %% [markdown]
# Выделим группы символов из посадочного талона, где:
# - первые 2 символа - это авиакомпания;
# - 4 следующие символа - номер рейса;
# - 3 следующих символа - аэропорт отправления;
# - 3 следюущих - аэропорт прибытия;
# - оставшиеся - дата рейса.
#
# Предполагаем, что все буквы всегда в верхнем регистре

# %%
flight = 'Boarding pass: LA4214 AER-CDB 06NOV'

# %%
regex_flight = r'([A-Z]{2})(\d{4})\s([A-Z]{3})-([A-Z]{3})\s(\d{2}[A-Z]{3})'

flight_match_result = re.search(regex_flight, flight)
print(flight_match_result.group())
# Out:
# LA4214 AER-CDB 06NOV

# %% [markdown]
# Переведем даты к другому формату при помощи групп

# %%
date = 'rehrth yery e 08/30/1991 eroyhoerjy oejyj epyjpo'
re.sub(r'(\d\d)/(\d\d)/(\d{4})', r'\2.\1.\3', date)
# Out:
# 'rehrth yery e 30.08.1991 eroyhoerjy oejyj epyjpo'

# %% [markdown]
# Позиционная проверка (lookaround) – используется при поиске шаблона, которому обязательно предшествует или следует другой шаблон.
#
# `?=` - Положительный lookahead (ищет шаблон, если он находится до указанной группы)
# `?!` - Отрицательный lookahead (ищет шаблон, если он не находится до указанной группы)
# `?<=` - Положительный lookbehind (ищет шаблон, если он находится после указанной группы)
# `?<!` - Отрицательный lookbehind (ищет шаблон, если он не находится после указанной группы)

# %%
# lookaround. Достанем имена только загруженных файлов
report = 'файл 11.txt загружен, файл 22.txt загружен, файл 33.txt ошибка'
find_downloaded = r'\d+\.txt(?=\sзагружен)'
files_error = r'\d+\.txt(?!\sзагружен)'
re.findall(find_downloaded, report)
re.findall(files_error, report)

# %% [markdown]
# **Практика**. Получить только рублевые цены из строки (без валюты)
# ```prices = 'RUB4.44, RUB10.88, EUR0.99, RUB99.99'```

# %% [markdown]
# [Документация по регулярным выражениям](https://docs.python.org/3/library/re.html)
# [Тестер регулярных выражений](https://regex101.com/)
# [Хорошая понятная статья по регулярным выражениям](https://tproger.ru/translations/regular-expression-python/)
# https://regexcrossword.com/howtoplay

# %% [markdown]
# # Файлы

# %% [markdown]
# Файл — именованная область данных на носителе информации.

# %% [markdown]
# Python поддерживает множество различных типов файлов, но условно их можно разделить на два виде: текстовые и бинарные.
#
# Текстовые файлы - это к примеру файлы с расширением csv, txt, html, в общем любые файлы, которые сохраняют информацию в текстовом виде.
#
# Бинарные файлы - это изображения, аудио и видеофайлы и т.д. В зависимости от типа файла работа с ним может немного отличаться.

# %% [markdown]
# <code> with open(file, mode) as file_obj:
#     инструкции </code>
#
# Эта конструкция определяет для открытого файла переменную file_obj и выполняет набор инструкций. После их выполнения файл автоматически закрывается. Даже если при выполнении инструкций в блоке with возникнут какие-либо исключения, то файл все равно закрывается.

# %%
# запись в файл (аргумент w)
with open("hello.txt", "w") as f:
    f.write("hello world")

# %%
# при таком режиме всегда происходит перезапись содержимого
with open("hello.txt", "w") as f:
    f.write("goodbye world")

# %%
# добавим ещё одну строку (аргумент a)
with open("hello.txt", "a") as f:
    f.write("\ngoodbye world")

# %%
# читаем файл построчно (аргумент r, используется по умолчанию)
with open("hello.txt", 'r') as f:
    for line in f:
        print(line, end="")
# Out:
# goodbye world
# goodbye world

# %%
# читаем файл целиком
with open("hello.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# goodbye world
# goodbye world

# %%
# имя файла
FILENAME = "messages.txt"
# определяем пустой список
messages = []
 
for i in range(4):
    message = input(f"Введите строку {i+1}: ")
    messages.append(message + "\n")

# запись списка в файл
with open(FILENAME, "a") as f:
    for message in messages:
        f.write(message)

# считываем сообщения из файла
print("Считанные сообщения")
with open(FILENAME, "r") as f:
    for message in f:
        print(message, end="")
# Out:
# Введите строку 1: строка 1
# Введите строку 2: строка 2
# Введите строку 3: строка 3
# Введите строку 4: щ4крп9укпщукрш
# Считанные сообщения
# line
# line 2
# line 3
# line 4
# строка 1
# строка 2
# строка 3
# щ4крп9укпщукрш

# %% [markdown]
# Для того чтобы работать с файлами в Питоне следует также понимать принципы работы path
# Рабочая библиотека [os](https://python-scripts.com/import-os-example)

# %%
import os
os.getcwd()
# Out:
# 'E:\\Work\\SkillFactory\\skillfactory_materials\\strings'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'case.csv',
#  'hello.txt',
#  'messages.txt',
#  'strings_10_04_21.ipynb',
#  'strings_22_05_2021.ipynb',
#  'strings_forme.ipynb',
#  'strings_practice-Copy1.ipynb',
#  'strings_practice.ipynb',
#  'strings_practice_26_06_21.ipynb']

# %%
[i for i in os.listdir() if i.endswith('txt')]
# Out:
# ['hello.txt', 'messages.txt']

# %%
# прочитаем файл с рассекреченными делами СовНарКома СССР
with open('case.csv') as f:
    for line in f:
        print(line)
# Out:
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2057.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2058.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёР№ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„–в„– 155-49, 165-51)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2059.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2060.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2061.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2062.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2063.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2064.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2065.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2066.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2067.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2068.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2069.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2070.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2071.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2072.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2073.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2074.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2075.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2076.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2077.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2078.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2079.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2080.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2081.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2082.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2083.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2084.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2085.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2086.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2087.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2088.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2089.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 997-297СЃСЃ)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2090.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2091.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2092.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2093.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2094.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1981 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1981 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 1166-356)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2095.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 74-19)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2097.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2098.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2099.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 606-163СЃСЃ)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2100.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2101.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2102.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёР№ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„–в„– 841-223СЃСЃ, 856-232)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2103.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2104.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2105.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2106.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2107.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2108.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2109.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2110.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2111.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2112.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2113.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2114.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2115.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2116.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2117.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2118.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2119.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2120.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2121.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2122.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2123.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2124.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2125.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2126.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2127.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2128.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2129.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1982 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1982 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёР№ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„–в„– 1075-306, 1085-308)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2130.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2132.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 169-71)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2133.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 286-116СЃСЃ)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2134.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 392-141)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2135.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 566-192СЃСЃ)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2136.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2137.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2138.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2139.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 1046-334)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2140.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 1180-381)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2141.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2142.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2143.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2144.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2145.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2146.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2147.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2148.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2149.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2150.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2151.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2152.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2153.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2154.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2155.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2156.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2157.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2158.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2159.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2160.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2161.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2162.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2163.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2164.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1983 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1983 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 1208-403)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2165.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёР№ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„–в„– 72-18, 148-45, 168-47)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2167.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёР№ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„–в„– 212-60СЃСЃ, 345-90)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2168.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 628-142СЃСЃ)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2169.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2170.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 919-207)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2171.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2172.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2173.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2174.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёР№ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„–в„– 1065-257СЃСЃ, 2090-269)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2175.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2176.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2177.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2178.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2179.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2180.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2181.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2182.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2183.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2184.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2185.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2186.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2187.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2188.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2189.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2190.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2191.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2192.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2193.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2194.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2195.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2196.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 1157-292)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2197.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2198.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1984 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1984 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 1241-328)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2199.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 8-5)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2201.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 121-45)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2202.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2203.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 351-122)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2204.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 527-159)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2205.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2206.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2207.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 794-235СЃСЃ)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2208.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2209.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 967-293)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2210.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2211.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2212.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2213.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„– 1039-308)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2214.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2215.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2216.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2217.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2218.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2219.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2220.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2221.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2222.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2223.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2224.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2225.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2226.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2227.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2228.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2229.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2230.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2231.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2232.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2233.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2234.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2235.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2236.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2237.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2238.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі. (Р·Р° РёСЃРєР»СЋС‡РµРЅРёРµРј РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёР№ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  в„–в„– 1129-332СЃСЃ, 1239-357)	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2239.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991
#
# 1985 Рі.	РџРѕСЃС‚Р°РЅРѕРІР»РµРЅРёСЏ РЎРѕРІРµС‚Р° РјРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР  Р·Р° 1985 Рі.	Р“Рђ Р Р¤. Р¤. Р -5446. РћРї. 106СЃ. Р”. 2240.	Р Р°СЃСЃРµРєСЂРµС‡РµРЅРѕ РІ 2018 РіРѕРґСѓ	РЎРѕРІРµС‚ РЅР°СЂРѕРґРЅС‹С… РєРѕРјРёСЃСЃР°СЂРѕРІ РЎРЎРЎР  вЂ“ РЎРѕРІРµС‚ РњРёРЅРёСЃС‚СЂРѕРІ РЎРЎРЎР . 1921вЂ“1991

# %% [markdown]
# Иногда следует явно указать кодировку
# Подробнее про кодировки можно почитать, напримерь [здесь](https://tproger.ru/translations/unicode-and-encoding-python-guide/)

# %%
with open('case.csv', encoding='utf-8') as f:
    for line in f:
        print(line)
# Out:
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2057.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2058.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г. (за исключением Постановлений Совета министров СССР №№ 155-49, 165-51)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2059.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2060.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2061.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2062.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2063.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2064.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2065.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2066.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2067.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2068.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2069.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2070.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2071.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2072.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2073.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2074.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2075.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2076.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2077.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2078.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2079.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2080.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2081.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2082.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2083.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2084.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2085.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2086.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2087.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2088.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2089.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г. (за исключением Постановления Совета министров СССР № 997-297сс)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2090.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2091.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2092.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2093.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2094.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1981 г.	Постановления Совета министров СССР за 1981 г. (за исключением Постановления Совета министров СССР № 1166-356)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2095.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г. (за исключением Постановления Совета министров СССР № 74-19)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2097.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2098.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2099.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г. (за исключением Постановления Совета министров СССР № 606-163сс)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2100.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2101.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2102.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г. (за исключением Постановлений Совета министров СССР №№ 841-223сс, 856-232)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2103.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2104.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2105.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2106.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2107.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2108.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2109.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2110.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2111.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2112.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2113.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2114.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2115.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2116.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2117.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2118.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2119.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2120.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2121.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2122.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2123.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2124.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2125.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2126.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2127.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2128.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2129.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1982 г.	Постановления Совета министров СССР за 1982 г. (за исключением Постановлений Совета министров СССР №№ 1075-306, 1085-308)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2130.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2132.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г. (за исключением Постановления Совета министров СССР № 169-71)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2133.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г. (за исключением Постановления Совета министров СССР № 286-116сс)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2134.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г. (за исключением Постановления Совета министров СССР № 392-141)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2135.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г. (за исключением Постановления Совета министров СССР № 566-192сс)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2136.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2137.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2138.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2139.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г. (за исключением Постановления Совета министров СССР № 1046-334)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2140.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г. (за исключением Постановления Совета министров СССР № 1180-381)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2141.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2142.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2143.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2144.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2145.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2146.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2147.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2148.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2149.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2150.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2151.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2152.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2153.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2154.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2155.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2156.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2157.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2158.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2159.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2160.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2161.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2162.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2163.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2164.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1983 г.	Постановления Совета министров СССР за 1983 г. (за исключением Постановления Совета министров СССР № 1208-403)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2165.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г. (за исключением Постановлений Совета министров СССР №№ 72-18, 148-45, 168-47)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2167.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г. (за исключением Постановлений Совета министров СССР №№ 212-60сс, 345-90)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2168.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г. (за исключением Постановления Совета министров СССР № 628-142сс)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2169.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2170.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г. (за исключением Постановления Совета министров СССР № 919-207)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2171.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2172.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2173.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2174.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г. (за исключением Постановлений Совета министров СССР №№ 1065-257сс, 2090-269)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2175.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2176.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2177.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2178.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2179.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2180.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2181.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2182.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2183.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2184.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2185.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2186.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2187.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2188.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2189.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2190.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2191.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2192.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2193.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2194.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2195.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2196.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г. (за исключением Постановления Совета министров СССР № 1157-292)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2197.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2198.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1984 г.	Постановления Совета министров СССР за 1984 г. (за исключением Постановления Совета министров СССР № 1241-328)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2199.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г. (за исключением Постановления Совета министров СССР № 8-5)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2201.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г. (за исключением Постановления Совета министров СССР № 121-45)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2202.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2203.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г. (за исключением Постановления Совета министров СССР № 351-122)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2204.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г. (за исключением Постановления Совета министров СССР № 527-159)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2205.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2206.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2207.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г. (за исключением Постановления Совета министров СССР № 794-235сс)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2208.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2209.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г. (за исключением Постановления Совета министров СССР № 967-293)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2210.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2211.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2212.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2213.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г. (за исключением Постановления Совета министров СССР № 1039-308)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2214.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2215.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2216.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2217.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2218.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2219.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2220.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2221.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2222.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2223.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2224.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2225.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2226.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2227.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2228.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2229.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2230.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2231.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2232.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2233.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2234.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2235.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2236.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2237.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2238.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г. (за исключением Постановлений Совета министров СССР №№ 1129-332сс, 1239-357)	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2239.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991
#
# 1985 г.	Постановления Совета министров СССР за 1985 г.	ГА РФ. Ф. Р-5446. Оп. 106с. Д. 2240.	Рассекречено в 2018 году	Совет народных комиссаров СССР – Совет Министров СССР. 1921–1991

# %% [markdown]
# Посчитаем количество дел за 1983 год

# %%
res = 0
with open('case.csv', encoding='utf-8') as f:
    for line in f:
#         print(line.split())
        if line.split()[0] == '1983':
            res += 1
res
# Out:
# 34

# %% [markdown]
# **Практика**. Определим, какие вообще года упоминаются в файле. И посчитаем, в каком году было больше всего дел

# %%
res = []
with open('case.csv', encoding='utf-8') as f:
    for line in f:
        res.append(line.split()[0])

for year in set(res):
    print(f'{year}: {res.count(year)}')
# Out:
# 1983: 34
# 1984: 33
# 1985: 40
# 1982: 34
# 1981: 39

# %% [markdown]
# ### Спасибо за внимание! Буду рад ответить на ваши вопросы
# Форма ОС: https://forms.gle/y8xaFwJqtbFSjUeG8
