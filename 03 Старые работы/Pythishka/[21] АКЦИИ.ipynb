# %%
import pandas as pd

# %%
pd.read_csv('stocks_financemarker.csv')
# Out:
#                           Название  Капитализация  Сектор    P/E  P/FCF  \
# 0                              МТС      8712.4557      50   9.70  23.11
# 1   Mobile TeleSystems Public Join      8177.1556      50   9.49  22.89
# 2                    ГМК Норникель     49419.5569      15   6.55   9.05
# 3                        Лензолото       196.8338      15   3.27   2.10
# 4                        Лензолото       196.8338      15   3.27   2.10
# ..                             ...            ...     ...    ...    ...
# 85                             БСП       568.3147      40   2.85  -1.24
# 86                             БСП       568.3147      40   2.85  -1.24
# 87                            МГТС      2572.9990      50  13.14  17.45
# 88                            МГТС      2572.9990      50  13.14  17.45
# 89                     Абрау Дюрсо       264.7201      30  12.66  20.57
#
#      P/BV   P/S  EV/EBITDA  EV/S  EV/EBIT  Див-д, частота  Debt/EBITDA  \
# ...

# %%
pd.read_csv('stocks_financemarker (123).csv')
# Out:
#                 Название  Капитализация  Сектор    P/E   P/BV    P/S  EV/EBIT  \
# 0                    МТС      8712.4557      50   9.70  79.65   1.24     8.40
# 1          ГМК Норникель     49419.5569      15   6.55  10.11   2.69     5.43
# 2   Headhunter Group PLC      2732.7804      20  59.80  55.46  17.27    42.06
# 3                    ТЗА        12.7122      20   7.22   6.58   0.42     5.18
# 4                  Полюс     24772.9138      15  10.02   8.66   4.61     8.21
# 5                  Полюс     24772.9138      15  10.02   8.66   4.61     8.21
# 6                 ГК ПИК     11731.8000      60   6.22   3.85   1.98    11.73
# 7               АстрЭнСб        12.9258      55   7.60   4.59   0.08     5.06
# 8                   НЛМК     17676.9346      15   5.90   3.03   1.56     5.19
# 9                   НЛМК     17676.9346      15   5.90   3.03   1.56     5.19
# 10      Мордовэнергосбыт         9.4298      55   5.75   2.84   0.10     6.09
# ...

# %%
import random
 
result = []
current = ''
# nexxt = ''
# count = 1
total = 0
# summ = 0
s = 0
# nexxt = random.choice('OR')
# result.append(nexxt)
# num_updates = 0 
# print(result)
# while s <= 10:
    
for i in range(100):
    nexxt = random.choice('OR')
    result.append(nexxt)
    total += 1
    if nexxt == current:
        count += 1
        if count == 3:
            break
    else:
        count = 1
    current = nexxt
print(result, "Attempts: ", total)
print(total)
print(s)
# Out:
# ['O', 'O', 'R', 'R', 'R'] Attempts:  5
# 5
# 0

# %%
import random
 
result = []
current = ''
# nexxt = ''
# count = 1
total = 0
# summ = 0
s = 0
# nexxt = random.choice('OR')
# result.append(nexxt)
# num_updates = 0 
# print(result)
while s <= 2:
    for i in range(100):
        nexxt = random.choice('OR')
        result.append(nexxt)
        total += 1
        if nexxt == current:
            count += 1
            if count == 3:
                break
        else:
            count = 1
        current = nexxt
# print(result, "Attempts: ", total)
s = s + 1
# print(total)
print(s)
