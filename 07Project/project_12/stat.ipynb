# %% [markdown]
# https://script.google.com/macros/s/AKfycbx_m-8lsZCBR4MsQ9EgmEYkfoWXkRw59EjWhwQfkdIjCYnsK7gnoHHlAGjUlwaqW-2w/exec

# %%
import streamlit as st
import gspread

# 🔑 URL таблицы (сделайте таблицу доступной для всех, у кого есть ссылка)
SPREADSHEET_URL = 'https://docs.google.com/spreadsheets/d/1Vc2E-v97CZ80GP-yo1PAKJ9kWi-trVdPGeJGVzqr92k/edit?usp=sharing'



# 📁 Подключаемся к Google Sheets
try:
    # Авторизация по открытой ссылке (без Google Cloud)
    client = gspread.service_account_from_dict(st.secrets["gcp_service_account"])
    sheet = client.open_by_url(SPREADSHEET_URL).sheet1
    st.success('Подключение к Google Sheets успешно выполнено! ✅')
except Exception as e:
    st.error(f'Ошибка подключения к Google Sheets: {e}')

# ✅ Добавление строки данных
if st.button('Добавить данные'):
    new_data = ['Иван', '3', '195000']  # Пример данных
    try:
        sheet.append_row(new_data)
        st.success('Данные успешно добавлены в Google таблицу!')
    except Exception as e:
        st.error(f'Ошибка при добавлении данных: {e}')
# Out:
# 2024-12-14 09:49:55.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 09:49:57.359
# ...
#   command:
#
#     streamlit run C:\Users\Георгий\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-12-14 09:49:57.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 09:49:57.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 09:49:57.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 09:49:57.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-14 09:49:57.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
pip install gspread oauth2client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import streamlit as st
import pandas as pd
import os

# Проверяем, существует ли файл для хранения данных
FILE_NAME = 'user_data.csv'

# Создаем файл с заголовками, если его нет
if not os.path.exists(FILE_NAME):
    df = pd.DataFrame(columns=['Имя', 'Баланс'])
    df.to_csv(FILE_NAME, index=False)

# Ввод данных пользователем
st.title('Сбор данных пользователей')
name = st.text_input('Введите ваше имя:')
balance = st.number_input('Введите начальный баланс:', min_value=0, value=200000)

# Кнопка для сохранения данных
if st.button('Отправить'):
    # Сохраняем данные в файл
    new_data = {'Имя': name, 'Возраст': age, 'Баланс': balance}
    df = pd.read_csv(FILE_NAME)
    df = df.append(new_data, ignore_index=True)
    df.to_csv(FILE_NAME, index=False)
    st.success('Данные успешно сохранены!')

# Отображаем текущую статистику всех пользователей
st.title('📊 Статистика пользователей')
if os.path.exists(FILE_NAME):
    df = pd.read_csv(FILE_NAME)
    st.write('Всего пользователей:', len(df))
    st.write(df)
# Out:
# 2024-12-13 14:46:54.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:46:54.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:46:54.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:46:54.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:46:54.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:46:54.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:46:54.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd
import os

# Проверяем, существует ли файл для хранения данных
FILE_NAME = 'user_data.csv'

# Создаём файл с заголовками, если его нет
if not os.path.exists(FILE_NAME):
    df = pd.DataFrame(columns=['Имя'])
    df.to_csv(FILE_NAME, index=False)

# Ввод имени пользователем
st.title('Сбор данных пользователей')
name = st.text_input('Введите ваше имя:')

# Кнопка для сохранения данных
if st.button('Отправить'):
    new_data = {'Имя': name}
    df = pd.read_csv(FILE_NAME)
    df = df.append(new_data, ignore_index=True)
    df.to_csv(FILE_NAME, index=False)
    st.success('Данные успешно сохранены!')

# Отображаем текущую статистику всех пользователей
st.title('📊 Статистика пользователей')
if os.path.exists(FILE_NAME):
    df = pd.read_csv(FILE_NAME)
    st.write('Всего пользователей:', len(df))
    st.write(df)
# Out:
# 2024-12-13 14:26:43.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:26:43.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:26:43.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:26:43.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:26:43.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:26:43.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:26:43.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Файл с данными
FILE_NAME = 'user_data.csv'

# Создаём файл с заголовками, если его нет
if not os.path.exists(FILE_NAME):
    df = pd.DataFrame(columns=['Имя'])
    df.to_csv(FILE_NAME, index=False)

# Ввод имени пользователем
st.title('Сбор данных пользователей')
name = st.text_input('Введите ваше имя:')

# Кнопка для сохранения данных
if st.button('Отправить'):
    new_data = {'Имя': name}
    df = pd.read_csv(FILE_NAME)
    df = df.append(new_data, ignore_index=True)
    df.to_csv(FILE_NAME, index=False)
    st.success('Данные успешно сохранены!')

# Отображаем текущую статистику всех пользователей
st.title('📊 Статистика пользователей')

if os.path.exists(FILE_NAME):
    df = pd.read_csv(FILE_NAME)
    st.write('Всего пользователей:', len(df))
    st.write(df)

    # 📈 Раздел для визуализации
    st.title('Визуализация данных')

    # 1️⃣ Гистограмма частоты имён
    st.subheader('📊 Гистограмма частоты имён')
    fig, ax = plt.subplots()
    sns.countplot(y='Имя', data=df, order=df['Имя'].value_counts().index, palette='viridis', ax=ax)
    ax.set_title('Частота имен пользователей')
    ax.set_xlabel('Количество')
    ax.set_ylabel('Имя')
    st.pyplot(fig)  # Отображение графика

    # 2️⃣ Линейный график роста количества пользователей
    st.subheader('📈 Линейный график роста количества пользователей')
    fig, ax = plt.subplots()
    df['Номер пользователя'] = range(1, len(df) + 1)
    ax.plot(df['Номер пользователя'], marker='o', linestyle='-', color='tab:blue')
    ax.set_title('Рост количества пользователей с течением времени')
    ax.set_xlabel('Количество добавленных пользователей')
    ax.set_ylabel('Идентификатор пользователя')
    st.pyplot(fig)  # Отображение графика

    # 3️⃣ Круговая диаграмма (распределение уникальных имен)
    st.subheader('🧁 Круговая диаграмма распределения уникальных имён')
    fig, ax = plt.subplots()
    name_counts = df['Имя'].value_counts()
    ax.pie(name_counts, labels=name_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
    ax.set_title('Распределение имён пользователей')
    st.pyplot(fig)  # Отображение графика

    # 4️⃣ Фильтр для отображения определённых пользователей
    st.subheader('🔍 Фильтр по имени')
    unique_names = df['Имя'].unique()
    selected_name = st.selectbox('Выберите имя для фильтрации:', unique_names)
    filtered_df = df[df['Имя'] == selected_name]
    st.write(f'Пользователи с именем {selected_name}:', filtered_df)

    # Дополнительная информация
    st.write('---')
    st.write('🔄 Обновляйте данные и наблюдайте за изменениями в графиках.')
# Out:
# 2024-12-13 14:30:19.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:30:19.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:30:19.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:30:19.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:30:19.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:30:19.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:30:19.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Файл с данными
FILE_NAME = 'user_data.csv'

# Создаём файл с заголовками, если его нет
if not os.path.exists(FILE_NAME):
    df = pd.DataFrame(columns=['Имя'])
    df.to_csv(FILE_NAME, index=False)

# Чтение файла
try:
    df = pd.read_csv(FILE_NAME)
except Exception as e:
    st.error(f'Ошибка загрузки файла: {e}')
    df = pd.DataFrame(columns=['Имя'])

# Ввод имени пользователем
st.title('Сбор данных пользователей')
name = st.text_input('Введите ваше имя:')

# Кнопка для сохранения данных
if st.button('Отправить'):
    if name.strip():  # Проверяем, что имя не пустое
        new_data = {'Имя': name}
        df = pd.read_csv(FILE_NAME)
        df = df.append(new_data, ignore_index=True)
        df.to_csv(FILE_NAME, index=False)
        st.success('Данные успешно сохранены!')
    else:
        st.error('Имя не может быть пустым!')

# Отображаем текущую статистику всех пользователей
st.title('📊 Статистика пользователей')

if os.path.exists(FILE_NAME):
    df = pd.read_csv(FILE_NAME)
    st.write('Всего пользователей:', len(df))
    st.write(df)

    # 📈 Раздел для визуализации
    st.title('Визуализация данных')

    if df.empty:
        st.warning('Данных для отображения графиков пока нет. Добавьте хотя бы одного пользователя.')
    else:
        # 1️⃣ Гистограмма частоты имён
        st.subheader('📊 Гистограмма частоты имён')
        fig, ax = plt.subplots()
        sns.countplot(y='Имя', data=df, order=df['Имя'].value_counts().index, palette='viridis', ax=ax)
        ax.set_title('Частота имен пользователей')
        ax.set_xlabel('Количество')
        st.pyplot(fig)
# Out:
# 2024-12-13 14:33:44.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:33:44.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:33:44.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:33:44.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:33:44.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:33:44.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:33:44.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# 📁 Файл с данными
FILE_NAME = 'user_data.csv'

# Создаём файл с заголовками, если его нет
if not os.path.exists(FILE_NAME):
    df = pd.DataFrame(columns=['Имя'])
    df.to_csv(FILE_NAME, index=False)

# Чтение файла
try:
    df = pd.read_csv(FILE_NAME)
except Exception as e:
    st.error(f'Ошибка загрузки файла: {e}')
    df = pd.DataFrame(columns=['Имя'])

# Показываем загруженные данные для отладки
st.write('📂 Загруженные данные из файла user_data.csv:', df)

# 🔥 Ввод имени пользователем
st.title('Сбор данных пользователей')
name = st.text_input('Введите ваше имя:')

# Кнопка для сохранения данных
if st.button('Отправить'):
    if name.strip():  # Проверяем, что имя не пустое
        new_data = {'Имя': name}
        df = pd.read_csv(FILE_NAME)
        df = df.append(new_data, ignore_index=True)
        df.to_csv(FILE_NAME, index=False)
        st.success('Данные успешно сохранены!')
        st.write('Обновленные данные:', df)
    else:
        st.error('Имя не может быть пустым!')

# Отображаем текущую статистику всех пользователей
st.title('📊 Статистика пользователей')

if os.path.exists(FILE_NAME):
    try:
        df = pd.read_csv(FILE_NAME)
    except Exception as e:
        st.error(f'Ошибка загрузки файла: {e}')
        df = pd.DataFrame(columns=['Имя'])

    st.write('Всего пользователей:', len(df))
    st.write('DataFrame (df):', df)  # Показываем содержимое файла

    # 📈 Раздел для визуализации
    st.title('Визуализация данных')

    if df.empty:
        st.warning('Данных для отображения графиков пока нет. Добавьте хотя бы одного пользователя.')
    else:
        # 1️⃣ Гистограмма частоты имён
        st.subheader('📊 Гистограмма частоты имён')
        fig, ax = plt.subplots()
        sns.countplot(y='Имя', data=df, order=df['Имя'].value_counts().index, palette='viridis', ax=ax)
        ax.set_title('Частота имен пользователей')
        ax.set_xlabel('Количество')
        st.pyplot(fig)
# Out:
# 2024-12-13 14:36:07.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:36:07.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:36:07.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:36:07.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:36:07.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:36:07.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:36:07.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# 📁 Название файла с данными
FILE_NAME = 'user_data.csv'

# Создаём файл с заголовками, если его нет
if not os.path.exists(FILE_NAME):
    df = pd.DataFrame(columns=['Имя'])
    df.to_csv(FILE_NAME, index=False)

# Чтение файла
try:
    df = pd.read_csv(FILE_NAME)
except Exception as e:
    st.error(f'Ошибка загрузки файла: {e}')
    df = pd.DataFrame(columns=['Имя'])

# Показываем загруженные данные для отладки
st.write('📂 Загруженные данные из файла user_data.csv:', df)

# 🔥 Ввод имени пользователем
st.title('Сбор данных пользователей')
name = st.text_input('Введите ваше имя:')

# Кнопка для сохранения данных
if st.button('Отправить'):
    if name.strip():  # Проверяем, что имя не пустое
        new_data = {'Имя': name}
        df = pd.read_csv(FILE_NAME)
        df = pd.concat([df, pd.DataFrame([new_data])], ignore_index=True)
        df.to_csv(FILE_NAME, index=False)
        st.success('Данные успешно сохранены!')
    else:
        st.error('Имя не может быть пустым!')

# 🔍 Отображаем текущую статистику всех пользователей
st.title('📊 Статистика пользователей')

# Чтение обновлённых данных
try:
    df = pd.read_csv(FILE_NAME)
except Exception as e:
    st.error(f'Ошибка загрузки файла: {e}')
    df = pd.DataFrame(columns=['Имя'])

st.write('Всего пользователей:', len(df))
st.write('DataFrame (df):', df)  # Показываем содержимое файла

# 📈 Визуализация графиков
st.title('Визуализация данных')

if df.empty:
    st.warning('Данных для отображения графиков пока нет. Добавьте хотя бы одного пользователя.')
else:
    # ✅ 1️⃣ Гистограмма частоты имён
    st.subheader('📊 Гистограмма частоты имён')
    fig, ax = plt.subplots()
    sns.countplot(y='Имя', data=df, order=df['Имя'].value_counts().index, palette='viridis', ax=ax)
    ax.set_title('Частота имен пользователей')
    ax.set_xlabel('Количество')
    st.pyplot(fig)
    plt.close(fig)

    # ✅ 2️⃣ Круговая диаграмма
    st.subheader('📈 Круговая диаграмма имен')
    name_counts = df['Имя'].value_counts()
    fig, ax = plt.subplots()
    ax.pie(name_counts, labels=name_counts.index, autopct='%1.1f%%', startangle=90)
    ax.set_title('Распределение имен пользователей')
    st.pyplot(fig)
    plt.close(fig)

    # ✅ 3️⃣ График числа пользователей с течением времени
    st.subheader('📉 Динамика добавления пользователей (фиктивный график)')
    df['Время'] = pd.date_range(start='2024-01-01', periods=len(df), freq='D')
    fig, ax = plt.subplots()
    sns.lineplot(x='Время', y=range(len(df)), data=df, marker='o', ax=ax)
    ax.set_title('Динамика добавления пользователей')
    plt.xticks(rotation=45)
    st.pyplot(fig)
    plt.close(fig)
# Out:
# 2024-12-13 14:47:02.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:47:02.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:47:02.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:47:02.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:47:02.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:47:02.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-13 14:47:02.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
